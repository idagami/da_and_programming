# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')
df_apps.head()
df_apps.shape
df_apps.columns
df_apps.describe()
df_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size_MBs        10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Android_Ver     10839 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1016.5+ KB

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.isna().values.any()
df_apps.isna().values.sum()
# Out:
# np.int64(1477)

# %%
df_apps.sample(5)
# Out:
#                                                     App             Category  \
# 9947  Disney Magic Kingdoms: Build Your Own Magical ...               FAMILY
# 108                         SK Bosnia Online EU Teplice               SPORTS
# 6578  AE + Aerie: Jeans, Dresses, Swimsuits & Bralettes             SHOPPING
# 667                                    EU GDPR RiskCalc             BUSINESS
# 2853                                            AY Sing  BOOKS_AND_REFERENCE
#
#       Rating  Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 9947    4.30   472584     91.00  10,000,000  Free     0       Everyone
# 108      NaN        2     10.00           5  Free     0       Everyone
# 6578    4.20    20476     28.00   1,000,000  Free     0       Everyone
# 667      NaN        1     13.00          50  Free     0       Everyone
# 2853    4.80      111     10.00       5,000  Free     0       Everyone
#
#                              Genres     Last_Updated   Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %%
df_apps.isna().values.sum()
# Out:
# np.int64(1475)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps[df_apps['Rating'].isna()]
# Out:
#                                                App            Category  \
# 0                          Ak Parti Yardım Toplama              SOCIAL
# 1                       Ain Arabic Kids Alif Ba ta              FAMILY
# 2     Popsicle Launcher for Android P 9.0 launcher     PERSONALIZATION
# 3                        Command & Conquer: Rivals              FAMILY
# 4                                       CX Network            BUSINESS
# ...                                            ...                 ...
# 5840                                Em Fuga Brasil              FAMILY
# 5862                    Voice Tables - no internet           PARENTING
# 6141                                Young Speeches  LIBRARIES_AND_DEMO
# 7035                                SD card backup               TOOLS
# 7175                     Android TV Remote Service               TOOLS
#
#       Rating  Reviews  Size_MBs   Installs  Type   Price Content_Rating  \
# ...

# %%
df_apps[df_apps['Type'].isna()]
# Out:
#                          App Category  Rating  Reviews  Size_MBs Installs  \
# 3  Command & Conquer: Rivals   FAMILY     NaN        0     19.00        0
#
#   Type Price Content_Rating    Genres
# 3  NaN     0   Everyone 10+  Strategy

# %%
df_apps_clean = df_apps.dropna(subset=['Rating'])
# df_apps_clean = df_apps.dropna()
df_apps_clean.head()
df_apps_clean.shape
# 10841 - 9367
# df_apps_clean.isna().values.any()
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
duplicated_rows.sort_values(by='App')
# Out:
#                                                      App            Category  \
# 6371                               10 Best Foods for You  HEALTH_AND_FITNESS
# 7159                          1800 Contacts - Lens Store             MEDICAL
# 2604                          2017 EMRA Antibiotic Guide             MEDICAL
# 5140                        21-Day Meditation Experience  HEALTH_AND_FITNESS
# 946                               420 BZ Budeze Delivery             MEDICAL
# ...                                                  ...                 ...
# 9635   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 9634   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 9632   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 10156                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 10159                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
#
# ...

# %%
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'], keep='last', inplace=True)
df_apps_clean.shape
# 9367 - 476
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8912\76966487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'], keep='last', inplace=True)
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10810     0           Teen  Social

# %%
df_apps_clean.describe()
# Out:
#         Rating       Reviews  Size_MBs
# count 8,199.00      8,199.00  8,199.00
# mean      4.17    255,319.81     20.10
# std       0.54  1,984,597.38     21.65
# min       1.00          1.00      0.01
# 25%       4.00        126.00      4.90
# 50%       4.30      3,014.00     11.00
# 75%       4.50     43,947.50     28.00
# max       5.00 78,128,208.00    100.00

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean['Rating'].max()
df_apps_clean[df_apps_clean.Rating == 5.0].sort_values(by='Reviews', ascending=False)
# Out:
#                                                     App   Category  Rating  \
# 2095                                         Ríos de Fe  LIFESTYLE    5.00
# 2438  FD Calculator (EMI, SIP, RD & Loan Eligilibility)    FINANCE    5.00
# 3115                                         Oración CX  LIFESTYLE    5.00
# 2107                     Barisal University App-BU Face     FAMILY    5.00
# 2069                                         Master E.K     FAMILY    5.00
# ...                                                 ...        ...     ...
# 321                                  FK CLASSIC FOR YOU   BUSINESS    5.00
# 312   30WPM Amateur ham radio Koch CW Morse code tra...     FAMILY    5.00
# 382                  DG OFF - 100% Free Coupons & Deals   SHOPPING    5.00
# 151                                 EB Cash Collections   BUSINESS    5.00
# 99      Anatomy & Physiology Vocabulary Exam Review App    MEDICAL    5.00
#
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean['Size_MBs'].max()
df_apps_clean[df_apps_clean.Size_MBs == 100.0].sort_values(by='Reviews', ascending=False)
# df_apps_clean['Installs'].dtype
# Out:
#                                                     App            Category  \
# 10689                            Hungry Shark Evolution                GAME
# 10295                                   SimCity BuildIt              FAMILY
# 8718                  Mini Golf King - Multiplayer Game                GAME
# 9943                              Miami crime simulator                GAME
# 9945                                    Ultimate Tennis              SPORTS
# 8719                         Draft Simulator for FUT 18              SPORTS
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 9944                       Gangster Town: Vice District              FAMILY
# 7926                                          Post Bank             FINANCE
# 7928                      Stickman Legends: Shadow Wars                GAME
# 7927                        The Walking Dead: Our World                GAME
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10811                                           Facebook              SOCIAL
# 10797                                 WhatsApp Messenger       COMMUNICATION
# 10810                                          Instagram              SOCIAL
# 10800           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10653                                     Clash of Clans              FAMILY
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10840                                     Subway Surfers                GAME
# 10830                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10592                                       Clash Royale              FAMILY
# 10769                                   Candy Crush Saga              FAMILY
# ...

# %%
((df_apps_clean
    .sort_values(by='Reviews', ascending=False)
    .head(50)
    ['Type']
    == 'Paid')
    .any()
)
# Out:
# np.False_

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title="Content rating", names=ratings.index, hole=0.6,)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean['Installs'].dtype
# Out:
# dtype('O')

# %%
installs = df_apps_clean.Installs.value_counts()
installs
# Out:
# Installs
# 1,000,000        1415
# 100,000          1095
# 10,000            986
# 10,000,000        937
# 1,000             698
# 5,000,000         607
# 500,000           503
# 50,000            457
# 5,000             425
# 100               303
# 50,000,000        204
# 500               199
# 100,000,000       189
# 10                 69
# 50                 56
# 500,000,000        24
# 1,000,000,000      20
# 5                   9
# 1                   3
# Name: count, dtype: int64

# %%
df_apps_clean = df_apps_clean.copy()
df_apps_clean['Installs'] = df_apps_clean['Installs'].str.replace(",", "")
df_apps_clean.sample(50)
installs = df_apps_clean.Installs.value_counts()
installs
# Out:
# Installs
# 1000000       1415
# 100000        1095
# 10000          986
# 10000000       937
# 1000           698
# 5000000        607
# 500000         503
# 50000          457
# 5000           425
# 100            303
# 50000000       204
# 500            199
# 100000000      189
# 10              69
# 50              56
# 500000000       24
# 1000000000      20
# 5                9
# 1                3
# Name: count, dtype: int64

# %%
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean['Installs'], downcast='integer', errors='coerce')
installs.sort_values(ascending=False)
installs.sort_index(ascending=False)
installs.index = installs.index.astype(int)
installs.sort_index(ascending=False)
# Out:
# Installs
# 1000000000      20
# 500000000       24
# 100000000      189
# 50000000       204
# 10000000       937
# 5000000        607
# 1000000       1415
# 500000         503
# 100000        1095
# 50000          457
# 10000          986
# 5000           425
# 1000           698
# 500            199
# 100            303
# 50              56
# 10              69
# 5                9
# 1                3
# Name: count, dtype: int64

# %%
df_apps_clean['Installs'].dtype
# Out:
# dtype('int32')

# %%
df_apps_clean[df_apps_clean.Installs == 1000000000]
# Out:
#                                             App             Category  Rating  \
# 10783                         Google Play Books  BOOKS_AND_REFERENCE    3.90
# 10797                        WhatsApp Messenger        COMMUNICATION    4.40
# 10798              Google Chrome: Fast & Secure        COMMUNICATION    4.30
# 10799                                     Gmail        COMMUNICATION    4.30
# 10800  Messenger – Text and Video Chat for Free        COMMUNICATION    4.00
# 10801                                  Hangouts        COMMUNICATION    4.00
# 10802             Skype - free IM & video calls        COMMUNICATION    4.10
# 10804                         Google Play Games               FAMILY    4.30
# 10810                                 Instagram               SOCIAL    4.50
# 10811                                  Facebook               SOCIAL    4.10
# 10812                                   Google+               SOCIAL    4.20
# ...

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
prices = df_apps_clean.Price.value_counts()
prices
# Out:
# Price
# 0         7595
# $2.99      109
# $0.99      104
# $4.99       68
# $1.99       59
#           ...
# $4.77        1
# $9.00        1
# $3.95        1
# $13.99       1
# $2.90        1
# Name: count, Length: 73, dtype: int64

# %%
df_apps_clean['Price'] = df_apps_clean['Price'].str.replace("$", "")
df_apps_clean.sample(50)
prices = df_apps_clean.Price.value_counts()
prices
# Out:
# Price
# 0        7595
# 2.99      109
# 0.99      104
# 4.99       68
# 1.99       59
#          ...
# 4.77        1
# 9.00        1
# 3.95        1
# 13.99       1
# 2.90        1
# Name: count, Length: 73, dtype: int64

# %%
df_apps_clean
# Out:
#                                                    App            Category  \
# 21                                 KBA-EZ Health Guide             MEDICAL
# 28                                            Ra Ga Ba                GAME
# 47                                             Mu.F.O.                GAME
# 82                                    Brick Breaker BR                GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App             MEDICAL
# ...                                                ...                 ...
# 10827                                     Google Drive        PRODUCTIVITY
# 10829                          Google Play Movies & TV       VIDEO_PLAYERS
# 10830                                          YouTube       VIDEO_PLAYERS
# 10834                                      Google News  NEWS_AND_MAGAZINES
# 10840                                   Subway Surfers                GAME
#
# ...

# %%
df_apps_clean['Price'] = pd.to_numeric(df_apps_clean['Price'], downcast='float', errors='coerce')
prices.sort_values(ascending=False)
prices.index.dtype
prices = df_apps_clean.Price.value_counts()
prices
# Out:
# Price
# 0.00     7595
# 2.99      109
# 0.99      104
# 4.99       68
# 1.99       59
#          ...
# 4.77        1
# 9.00        1
# 3.95        1
# 13.99       1
# 2.90        1
# Name: count, Length: 73, dtype: int64

# %%
prices.index = prices.index.astype(float)
prices.sort_index(ascending=False)
# Out:
# Price
# 400.00       1
# 399.99      11
# 389.99       1
# 379.99       1
# 299.99       1
#           ...
# 1.29         1
# 1.20         1
# 1.00         2
# 0.99       104
# 0.00      7595
# Name: count, Length: 73, dtype: int64

# %%
df_apps_clean.sort_values(by='Price', ascending=False).head(20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# those > 250 is 'bad data' as its a fake app created for scam.
most_expensive = df_apps_clean[df_apps_clean.Price > 250]
most_expensive
df_apps_clean.shape
df_apps_clean = df_apps_clean.drop(most_expensive.index)
df_apps_clean.shape
# Out:
# (8184, 10)

# %%
df_apps_clean['Revenue_estimate'] = df_apps_clean['Price'] * df_apps_clean['Installs']
df_apps_clean.head(30)
# Out:
#                                                    App             Category  \
# 21                                 KBA-EZ Health Guide              MEDICAL
# 28                                            Ra Ga Ba                 GAME
# 47                                             Mu.F.O.                 GAME
# 82                                    Brick Breaker BR                 GAME
# 99     Anatomy & Physiology Vocabulary Exam Review App              MEDICAL
# 114                                        FK Atlantas               SPORTS
# 126                                    Tablet Reminder              MEDICAL
# 128                                            CQ ESPM             BUSINESS
# 141                                  Clinic Doctor EHr              MEDICAL
# 151                                EB Cash Collections             BUSINESS
# 154                                            CZ-Help  BOOKS_AND_REFERENCE
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean.sort_values(by='Revenue_estimate', ascending=False).head(10)
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9224                      Minecraft       FAMILY    4.50  2375336     19.00
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7479            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 6082                   Weather Live      WEATHER    4.50    76593      4.75
# 6746     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
# 7633        Five Nights at Freddy's         GAME    4.60   100805     50.00
# 7954                    Bloons TD 5       FAMILY    4.60   190086     94.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# ...

# %%
(df_apps_clean.sort_values(by='Revenue_estimate', ascending=False).head(10)['Category'] == 'GAME').sum()
# Out:
# np.int64(4)

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.value_counts().count()
# Out:
# np.int64(33)

# %%
df_apps_clean.Category.value_counts()
top_10 = df_apps_clean.Category.value_counts()[:10]

# %%
df_apps_clean.Category.nunique()
# Out:
# 33

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
fig = px.bar(x=top_10.index, y=top_10.values)
fig.show()

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)
category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 38252676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97072000
# ART_AND_DESIGN         113233100
# DATING                 140912410
# EDUCATION              176851000
# FOOD_AND_DRINK         211677750
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               697018120
# ENTERTAINMENT          708660000
# HEALTH_AND_FITNESS    1144006220
# SPORTS                1296431465
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3931797200
# PHOTOGRAPHY           4658143130
# ...

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')
 
h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category', height=1200)
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
df_apps_count = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})
df_apps_count.rename(columns={'App': 'App_count'}, inplace=True)
df_apps_count
# Out:
#                      App_count
# Category
# ART_AND_DESIGN              59
# AUTO_AND_VEHICLES           73
# BEAUTY                      42
# BOOKS_AND_REFERENCE        169
# BUSINESS                   263
# COMICS                      54
# COMMUNICATION              256
# DATING                     134
# EDUCATION                  101
# ENTERTAINMENT               79
# EVENTS                      45
# FAMILY                    1675
# FINANCE                    296
# FOOD_AND_DRINK              94
# GAME                       880
# HEALTH_AND_FITNESS         244
# HOUSE_AND_HOME              61
# LIBRARIES_AND_DEMO          64
# LIFESTYLE                  297
# MAPS_AND_NAVIGATION        118
# MEDICAL                    291
# NEWS_AND_MAGAZINES         204
# PARENTING                   50
# PERSONALIZATION            298
# PHOTOGRAPHY                263
# PRODUCTIVITY               301
# SHOPPING                   180
# SOCIAL                     203
# ...

# %%
df_merged = pd.merge(df_apps_count, category_installs, on='Category', how="inner")
df_merged
# Out:
#                      App_count     Installs
# Category
# ART_AND_DESIGN              59    113233100
# AUTO_AND_VEHICLES           73     53129800
# BEAUTY                      42     26916200
# BOOKS_AND_REFERENCE        169   1665791655
# BUSINESS                   263    697018120
# COMICS                      54     44931100
# COMMUNICATION              256  11038241530
# DATING                     134    140912410
# EDUCATION                  101    176851000
# ENTERTAINMENT               79    708660000
# EVENTS                      45     15949410
# FAMILY                    1675   8859955490
# FINANCE                    296    455249400
# FOOD_AND_DRINK              94    211677750
# GAME                       880  10912762717
# HEALTH_AND_FITNESS         244   1144006220
# HOUSE_AND_HOME              61     97072000
# LIBRARIES_AND_DEMO          64     52083000
# LIFESTYLE                  297    503611120
# MAPS_AND_NAVIGATION        118    503267560
# ...

# %%
scat = px.scatter(x=df_merged.App_count, y=df_merged.Installs)
scat.show()

# %%
scat = px.scatter(df_merged, x='App_count', y='Installs')
scat.show()

# %%
scat = px.scatter(df_merged, x='App_count', y='Installs', color="Installs",
                 size='App_count', hover_name=df_merged.index, title='Category Concentration',)
scat.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
scat.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean.head(10)
# Out:
#                                                  App  Category  Rating  \
# 21                               KBA-EZ Health Guide   MEDICAL    5.00
# 28                                          Ra Ga Ba      GAME    5.00
# 47                                           Mu.F.O.      GAME    5.00
# 82                                  Brick Breaker BR      GAME    5.00
# 99   Anatomy & Physiology Vocabulary Exam Review App   MEDICAL    5.00
# 114                                      FK Atlantas    SPORTS    1.50
# 126                                  Tablet Reminder   MEDICAL    5.00
# 128                                          CQ ESPM  BUSINESS    5.00
# 141                                Clinic Doctor EHr   MEDICAL    5.00
# 151                              EB Cash Collections  BUSINESS    5.00
#
#      Reviews  Size_MBs  Installs  Type  Price Content_Rating    Genres  \
# 21         4     25.00         1  Free   0.00       Everyone   Medical
# ...

# %%
df_apps_clean.Genres.value_counts()
# Out:
# Genres
# Tools                       719
# Entertainment               467
# Education                   429
# Productivity                301
# Personalization             298
#                            ...
# Casual;Music & Video          1
# Tools;Education               1
# Role Playing;Brain Games      1
# Adventure;Education           1
# Lifestyle;Pretend Play        1
# Name: count, Length: 114, dtype: int64

# %%
df_genres_split = df_apps_clean.copy()
df_genres_split
df_genres_split.Genres.value_counts()
df_genres_split['Genres'] = df_genres_split['Genres'].str.split(';')
df_genres_split.head(50)
df_genres_split.Genres.value_counts()
# Out:
# Genres
# [Tools]                        719
# [Entertainment]                467
# [Education]                    429
# [Productivity]                 301
# [Personalization]              298
#                               ...
# [Casual, Music & Video]          1
# [Tools, Education]               1
# [Role Playing, Brain Games]      1
# [Adventure, Education]           1
# [Lifestyle, Pretend Play]        1
# Name: count, Length: 114, dtype: int64

# %%
df_exploded = df_genres_split.explode('Genres')
genres_counts = df_exploded['Genres'].value_counts()
df_exploded['Genres'].value_counts().nunique()
# Out:
# 50

# %%
df_exploded.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Revenue_estimate
# 21     25.00         1  Free   0.00       Everyone  Medical              0.00
# 28     20.00         1  Paid   1.49       Everyone   Arcade              1.49
# 47     16.00         1  Paid   0.99       Everyone   Arcade              0.99
# 82     19.00         5  Free   0.00       Everyone   Arcade              0.00
# 99      4.60         5  Free   0.00       Everyone  Medical              0.00

# %%
genres_counts.head()
# Out:
# Genres
# Tools            720
# Education        587
# Entertainment    498
# Action           304
# Productivity     301
# Name: count, dtype: int64

# %%
genre_count = df_exploded['Genres'].value_counts().reset_index()
genre_count.columns = ['Genre', 'Count']
genre_count
# Out:
#                       Genre  Count
# 0                     Tools    720
# 1                 Education    587
# 2             Entertainment    498
# 3                    Action    304
# 4              Productivity    301
# 5           Personalization    298
# 6                 Lifestyle    298
# 7                   Finance    296
# 8                   Medical    291
# 9                    Sports    270
# 10                 Business    263
# 11              Photography    263
# 12            Communication    257
# 13         Health & Fitness    246
# 14                   Casual    217
# 15         News & Magazines    204
# 16                   Social    203
# 17               Simulation    200
# 18           Travel & Local    187
# 19                   Arcade    185
# 20                 Shopping    180
# 21        Books & Reference    171
# 22  Video Players & Editors    150
# 23                   Dating    134
# 24                   Puzzle    123
# 25        Maps & Navigation    118
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar_v = px.bar(genre_count[:15], x='Genre', y='Count',
             color='Count', color_continuous_scale="Viridis", title='Top genres')
bar_v.update_layout(coloraxis_showscale=False, xaxis_title="Genre", yaxis_title="Number of Apps")
bar_v.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_clean.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
apps_cost = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App': pd.Series.count})
apps_cost.sort_values(by='Type').head(50)
# Out:
#                Category  Type   App
# 0        ART_AND_DESIGN  Free    56
# 25                 GAME  Free   804
# 27   HEALTH_AND_FITNESS  Free   233
# 29       HOUSE_AND_HOME  Free    61
# 59              WEATHER  Free    65
# 31            LIFESTYLE  Free   284
# 33  MAPS_AND_NAVIGATION  Free   113
# 35              MEDICAL  Free   228
# 37   NEWS_AND_MAGAZINES  Free   202
# 23       FOOD_AND_DRINK  Free    92
# 39            PARENTING  Free    48
# 43          PHOTOGRAPHY  Free   248
# 45         PRODUCTIVITY  Free   283
# 47             SHOPPING  Free   178
# 49               SOCIAL  Free   201
# 51               SPORTS  Free   240
# 53                TOOLS  Free   657
# 55     TRAVEL_AND_LOCAL  Free   179
# 57        VIDEO_PLAYERS  Free   145
# 41      PERSONALIZATION  Free   233
# 21              FINANCE  Free   289
# 30   LIBRARIES_AND_DEMO  Free    64
# 9                COMICS  Free    54
# 19               FAMILY  Free  1523
# 18               EVENTS  Free    45
# ...

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid = apps_cost.pivot(index='Category', columns='Type', values='App').reset_index()
df_free_vs_paid
# Out:
# Type             Category     Free   Paid
# 0          ART_AND_DESIGN    56.00   3.00
# 1       AUTO_AND_VEHICLES    72.00   1.00
# 2                  BEAUTY    42.00    NaN
# 3     BOOKS_AND_REFERENCE   161.00   8.00
# 4                BUSINESS   254.00   9.00
# 5                  COMICS    54.00    NaN
# 6           COMMUNICATION   234.00  22.00
# 7                  DATING   131.00   3.00
# 8               EDUCATION    99.00   2.00
# 9           ENTERTAINMENT    77.00   2.00
# 10                 EVENTS    45.00    NaN
# 11                 FAMILY 1,523.00 152.00
# 12                FINANCE   289.00   7.00
# 13         FOOD_AND_DRINK    92.00   2.00
# 14                   GAME   804.00  76.00
# 15     HEALTH_AND_FITNESS   233.00  11.00
# 16         HOUSE_AND_HOME    61.00    NaN
# 17     LIBRARIES_AND_DEMO    64.00    NaN
# 18              LIFESTYLE   284.00  13.00
# 19    MAPS_AND_NAVIGATION   113.00   5.00
# 20                MEDICAL   228.00  63.00
# ...

# %%
bar_double = px.bar(
    df_free_vs_paid,
    x='Category',
    y=['Free', 'Paid'],   # multiple columns for grouped bars
    barmode='group',
    title='Free VS Paid Apps by Category'
)

bar_double.update_xaxes(categoryorder='total descending')
bar_double.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
bar_double.show()

# %%
g_bar = px.bar(apps_cost,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

# g_bar.update_xaxes(categoryorder='total descending') 
g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
 
g_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean,
             x='Type',
             y='Installs',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()

# %%
df_paid_big_installs = df_apps_clean[
    (df_apps_clean['Installs'] > 9_999_999) & 
    (df_apps_clean['Type'] == 'Paid')
]
df_paid_big_installs
# Out:
#                 App Category  Rating  Reviews  Size_MBs  Installs  Type  \
# 8825  Hitman Sniper     GAME    4.60   408292     29.00  10000000  Paid
# 9224      Minecraft   FAMILY    4.50  2375336     19.00  10000000  Paid
#
#       Price Content_Rating                     Genres  Revenue_estimate
# 8825   0.99     Mature 17+                     Action      9,900,000.10
# 9224   6.99   Everyone 10+  Arcade;Action & Adventure     69,899,997.71

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box_categ = px.box(df_paid_apps, x='Category', y='Revenue_estimate', points='outliers')
box_categ.update_layout(yaxis=dict(type='log'), xaxis={'categoryorder':'min ascending'})
box_categ.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
info = df_paid_apps.describe()
info
# Out:
#        Rating      Reviews  Size_MBs      Installs  Price  Revenue_estimate
# count  589.00       589.00    589.00        589.00 589.00            589.00
# mean     4.27    11,180.20     19.61     96,998.95   4.48        347,214.91
# std      0.56   101,670.64     22.09    609,070.62   5.77      2,971,246.65
# min      1.00         1.00      0.01          1.00   0.99              0.99
# 25%      4.10        30.00      3.50      1,000.00   1.99          1,495.00
# 50%      4.40       206.00     11.00      5,000.00   2.99         14,950.00
# 75%      4.60     2,195.00     29.00     50,000.00   4.99         99,900.00
# max      5.00 2,375,336.00    100.00 10,000,000.00  79.99     69,899,997.71

# %%
median_price = info.loc['50%']['Price']
median_price = round(median_price, 2)
median_price
# Out:
# np.float64(2.99)

# %%
df_paid_apps.sort_values(by='Price', ascending=False)
# Out:
#                                                     App   Category  Rating  \
# 2282                          Vargo Anesthesia Mega App    MEDICAL    4.60
# 1407                                       LTC AS Legal    MEDICAL    4.00
# 2629                                   I am Rich Person  LIFESTYLE    4.20
# 2482                            A Manual of Acupuncture    MEDICAL    3.50
# 2208                                           EMT PASS    MEDICAL    3.40
# ...                                                 ...        ...     ...
# 7917                                  Cut the Rope GOLD     FAMILY    4.60
# 7957  League of Stickman 2018- Ninja Arena PVP(Dream...       GAME    4.40
# 7928                      Stickman Legends: Shadow Wars       GAME    4.40
# 47                                              Mu.F.O.       GAME    5.00
# 8825                                      Hitman Sniper       GAME    4.60
#
# ...

# %%
box_categ_price = px.box(df_paid_apps, x='Category', y='Price', points='outliers')
box_categ_price.update_layout(yaxis=dict(type='log'), xaxis={'categoryorder':'max descending'})
box_categ_price.add_hline(
    y=median_price,
    line_dash="dash",          # dashed line
    line_color="red",          # line color
    annotation_text="Median $2.99",  # optional label
    annotation_position="top right"
)
box_categ_price.show()
