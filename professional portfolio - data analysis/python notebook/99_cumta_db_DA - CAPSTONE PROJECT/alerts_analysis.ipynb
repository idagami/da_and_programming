# %% [markdown]
# # Alerts analysis from Cumta (Red Alerts in Israel) channel (end of 2018 - end of 2025)

# %% [markdown]
# #### Over 26,000 rockets, missiles, and drones have been fired toward Israel from multiple fronts since 7 Oct 2023.
# * 13,200 from Gaza
# * 12,400 from Lebanon (Hezbollah)
# * 400 from Iran (direct / indirect)
# * 180 from Yemen (Houthis)
# * 60 from Syria

# %%
import numpy as np
import pandas as pd
import sqlite3
import re
import csv
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
import json
import plotly.graph_objects as go
from scipy.stats import chisquare

# %pip install nbformat

# %%
pio.renderers.default = "notebook_connected"
pd.options.display.float_format = "{:,.2f}".format

# %%
conn = sqlite3.connect("cumta_alerts.db")
query = "SELECT * FROM alerts"
df = pd.read_sql_query(query, conn)
conn.close()
print(df.head())
# Out:
#    id       alert_datetime alert_type alert_zone               locality  \
# 0   1  2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South West)
# 1   2  2018-12-26 08:05:08  Red Alert        Dan       Tel Aviv (North)
# 2   3  2018-12-26 08:05:08  Red Alert        Dan     Tel Aviv (Central)
# 3   4  2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South East)
# 4   5  2018-12-26 08:05:08  Red Alert        Dan                   Azur
#
#      region  raw_message_id           city
# 0  Tel Aviv              42  Tel Aviv-Yafo
# 1  Tel Aviv              42  Tel Aviv-Yafo
# 2  Tel Aviv              42  Tel Aviv-Yafo
# 3  Tel Aviv              42  Tel Aviv-Yafo
# 4  Tel Aviv              42           Azur

# %% [markdown]
# ## Data / dataset exploration

# %%
df.shape
df.columns
# Out:
# Index(['id', 'alert_datetime', 'alert_type', 'alert_zone', 'locality',
#        'region', 'raw_message_id', 'city'],
#       dtype='object')

# %%
df.duplicated().sum() # 0
# Out:
# np.int64(0)

# %%
df.isna().values.any() # true
a = df[df.isna().any(axis=1)]
a.alert_zone.value_counts()
df.drop(a.index, inplace=True)
df.isna().values.any() # False
# Out:
# np.False_

# %% [markdown]
# ## Descriptive stats

# %%
df["alert_datetime"] = pd.to_datetime(df["alert_datetime"], errors="coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100304 entries, 0 to 100324
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              100304 non-null  int64
#  1   alert_datetime  100304 non-null  datetime64[ns]
#  2   alert_type      100304 non-null  object
#  3   alert_zone      100304 non-null  object
#  4   locality        100304 non-null  object
#  5   region          100304 non-null  object
#  6   raw_message_id  100304 non-null  int64
#  7   city            100304 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 6.9+ MB

# %%
df.describe() # no numeric values in df
# Out:
#               id                 alert_datetime  raw_message_id
# count 100,304.00                         100304      100,304.00
# mean   50,164.69  2024-08-16 21:00:04.060874752       30,928.46
# min         1.00            2018-12-26 08:05:08           42.00
# 25%    25,077.75     2024-05-17 15:01:15.500000       21,228.00
# 50%    50,168.50            2024-11-24 15:34:49       38,162.00
# 75%    75,246.25            2025-06-16 04:11:16       41,226.00
# max   100,325.00            2026-01-02 10:02:40       44,171.00
# std    28,961.96                            NaN       12,822.91

# %% [markdown]
# ## Alerts per region

# %%
alert_regions_count = df.region.value_counts().reset_index()
alert_regions_count.columns = ["alert_region", "count"]
# alert_regions_count = alert_regions_count.dropna(subset=["region"])
alert_regions_count = alert_regions_count.sort_values(by="count", ascending=False)
alert_regions_count
# Out:
#   alert_region  count
# 0        North  34227
# 1       Center  30554
# 2        South  18834
# 3         Yosh   6076
# 4    Jerusalem   3940
# 5        Haifa   3387
# 6     Tel Aviv   3286

# %%
import os

region_share_graph = px.pie(
    alert_regions_count,
    names="alert_region",
    values="count",
    title="Region share",
    hole=0.6,
    color_discrete_sequence=px.colors.qualitative.Set3,
)
region_share_graph.update_traces(textposition="outside", textinfo="percent+label")

# Save static image
region_share_graph.write_image(
    os.path.join("temp_imgs", "fig1.png")
)  # This is required

# %%
region_share_graph = px.pie(
    alert_regions_count,
    names="alert_region",
    values="count",
    title="Region share",
    hole=0.6,
    color_discrete_sequence=px.colors.qualitative.Set3,
)
region_share_graph.update_traces(textposition="outside", textinfo="percent+label")
region_share_graph.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="13bff2cb-33ec-4045-8f00-fbd1a696d341" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("13bff2cb-33ec-4045-8f00-fbd1a696d341")) {                    Plotly.newPlot(                        "13bff2cb-33ec-4045-8f00-fbd1a696d341",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"alert_region=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["North","Center","South","Yosh","Jerusalem","Haifa","Tel Aviv"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"s4UAAFp3AACSSQAAvBcAAGQPAAA7DQAA1gwAAA=="},"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"out ...

# %% [markdown]
# ## Alerts per zone

# %%
alert_zones_count = df.alert_zone.value_counts().reset_index()
alert_zones_count.columns = ["alert_zone", "count"]
alert_zones_count = alert_zones_count.sort_values(by="count", ascending=False)
alert_zones_count
# Out:
#                   alert_zone  count
# 0         Confrontation Line  14966
# 1                    Lakhish   9725
# 2                   HaShfela   8914
# 3                     Sharon   7434
# 4              Upper Galilee   6865
# ..                       ...    ...
# 60                מיני ישראל      1
# 61              יהוד מונוסון      1
# 62                      שוהם      1
# 63                      Nili      1
# 64  Milouot Industrial North      1
#
# [65 rows x 2 columns]

# %%
alert_zones_count.sort_index()
# alert_zones_count.to_csv(
#     "alert_zone_cleaned.csv", index=False, quoting=csv.QUOTE_NONE, escapechar="\\"
# )
# Out:
#                   alert_zone  count
# 0         Confrontation Line  14966
# 1                    Lakhish   9725
# 2                   HaShfela   8914
# 3                     Sharon   7434
# 4              Upper Galilee   6865
# ..                       ...    ...
# 60                מיני ישראל      1
# 61              יהוד מונוסון      1
# 62                      שוהם      1
# 63                      Nili      1
# 64  Milouot Industrial North      1
#
# [65 rows x 2 columns]

# %%
zones_graph = px.bar(
    alert_zones_count[:35],
    x="count",
    y="alert_zone",
    orientation="h",
    title="Alerts by the zone",
    text="count",
)

zones_graph.update_layout(
    height=1200,
    yaxis_title="Zone",
    xaxis_title="Alerts count",
    yaxis=dict(categoryorder="total ascending"),
)

zones_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5de44302-db23-45a4-b20a-5f59b79c50a8" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5de44302-db23-45a4-b20a-5f59b79c50a8")) {                    Plotly.newPlot(                        "5de44302-db23-45a4-b20a-5f59b79c50a8",                        [{"hovertemplate":"count=%{text}\u003cbr\u003ealert_zone=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":""},"textposition":"auto","x":{"dtype":"i2","bdata":"djr9JdIiCh3RGhcX1BaxEZsQQRBYCu8JzgkNBwwH\u002fQZCBusFXwU9BTMFIQVkBOUDcAPtAp4CpwElAQkBygCqAGkALwAcAA=="},"xaxis":"x","y":["Confrontation Line","Lakhish","HaShfela","Sharon","Upper Galilee","Gaza Envelope","Shfelat Yehuda","Yarkon","Dan","HaAmakim","Center Galilee","Shomron","Yehuda","Center Negev","Gaza Containment","West Lakhish","HaMifratz","Menashe","West Negev","HaCarmel","South Golan","Wadi Ara","Lower Galilee","South Negev","Jerusalem","Beit She'an Valley","North Golan","Dead Sea","Bika'a","Southern Shfela","Arava","Ashdod","Eilat","Center Negev \u002f Gaza Containment","Hefer"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3 ...

# %%
df_confline = df[df['alert_zone'] == "Confrontation Line"]
count_cl = df_confline.region.value_counts()
count_cl
# region
# North     14275
# South       475
# Center      215
# Out:
# region
# North     14276
# South       475
# Center      215
# Name: count, dtype: int64

# %% [markdown]
# As seen above, Confrontation Line is NOT some specific zone or location, it mostly refers to the area closest to the active war operation zone. Out of 14965 alerts in Confrontation Line, 14275 of them came in at the North.

# %%
# # below cell code DOES NOT work! saving it here in case choropleth introduces updates taht will enable to run it.
# # Why? Choropleth maps DO NOT work with Point geometries. Plotly expects: Polygon or MultiPolygon. 
# # However to use polygon i need proper regional boundaries which i won't find online.
# # Therefore am using a workaround and plotting a scatter graph on a picture of a map in a cell under this one.

# # loading my GeoJSON
# with open("alert_zones.geojson", "r", encoding="utf-8") as f:
#     geojson_data = json.load(f)

# # ensuring alert_zone names match exactly
# alert_zones_count["alert_zone"] = alert_zones_count["alert_zone"].str.strip()

# map_by_zone = px.choropleth_map(
#     alert_zones_count,
#     geojson=geojson_data,
#     locations="alert_zone",
#     featureidkey="properties.alert_zone",
#     color="count",
#     color_continuous_scale="Viridis",
#     map_style="carto-positron",
#     zoom=6,
#     center={"lat": 31.8, "lon": 35.0},
#     opacity=0.6,
# )

# map_by_zone.update_layout(margin=dict(l=0, r=0, t=0, b=0))
# map_by_zone.show()

# %%
with open("alert_zones.geojson", "r", encoding="utf-8") as f:
    geojson_data = json.load(f)
features = geojson_data["features"]

coords = []
for f in features:
    coords.append(
        {
            "alert_zone": f["properties"]["alert_zone"],
            "lon": f["geometry"]["coordinates"][0],
            "lat": f["geometry"]["coordinates"][1],
        }
    )

zones_coords = pd.DataFrame(coords)
zones_coords.head()
# Out:
#            alert_zone   lon   lat
# 0              Arabah 35.00 30.50
# 1               Arava 35.00 30.80
# 2              Ashdod 34.64 31.80
# 3  Beit She'an Valley 35.50 32.50
# 4        Beit Shemesh 34.99 31.73

# %%
zones_map_df = alert_zones_count.merge(zones_coords, on="alert_zone", how="inner")
zones_map_df
# Out:
#                   alert_zone  count   lon   lat
# 0         Confrontation Line  14966 35.00 31.50
# 1                    Lakhish   9725 34.80 31.50
# 2                   HaShfela   8914 34.80 31.80
# 3                     Sharon   7434 34.87 32.18
# 4              Upper Galilee   6865 35.30 33.00
# ..                       ...    ...   ...   ...
# 60                מיני ישראל      1 32.10 34.95
# 61              יהוד מונוסון      1 32.20 34.90
# 62                      שוהם      1 31.90 35.00
# 63                      Nili      1 31.75 35.00
# 64  Milouot Industrial North      1 31.50 34.90
#
# [65 rows x 4 columns]

# %%
fig = px.scatter_map(
    zones_map_df,
    lat="lat",
    lon="lon",
    size="count",
    color="count",
    color_continuous_scale="Viridis",
    size_max=40,
    zoom=6,
    center={"lat": 31.8, "lon": 35.0},
    map_style="carto-positron",
    hover_name="alert_zone",
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a73b3a49-7dea-4a70-ac17-e4acdbd6cf81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a73b3a49-7dea-4a70-ac17-e4acdbd6cf81")) {                    Plotly.newPlot(                        "a73b3a49-7dea-4a70-ac17-e4acdbd6cf81",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecount=%{marker.color}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Confrontation Line","Lakhish","HaShfela","Sharon","Upper Galilee","Gaza Envelope","Shfelat Yehuda","Yarkon","Dan","HaAmakim","Center Galilee","Shomron","Yehuda","Center Negev","Gaza Containment","West Lakhish","HaMifratz","Menashe","West Negev","HaCarmel","South Golan","Wadi Ara","Lower Galilee","South Negev","Jerusalem","Beit She'an Valley","North Golan","Dead Sea","Bika'a","Southern Shfela","Arava","Ashdod","Eilat","Center Negev \u002f Gaza Containment","Hefer","Arabah","Shfela","Hof HaCarmel","Zefat","Beit Shemesh","Samaria","Lev HaChula","Golan","Maale Adumim","Center Negev Beer Sheva","Dan Tel Aviv","Ye'arut HaCarmel (Carmel Forest)","מבטחים עמיעוז ישע","Pardes Hana","Yarkon Modi'in","שדרות איבים ניר עם","כרכור","Haifa","כפר נחום","Kfar Yehoshua Train Station","מטווח ניר עם","Nirim","קריית שמונה","מודיעין מכבים רעות","נאות קדומים","מיני ישראל","יהוד מונוסון","שוהם","Nili","Milouot Industrial North"],"lat":{"dtype":"f8","bdata":"AAAAAACAP0AAAAAAAIA\u002fQM3MzMzMzD9ABOj3\u002fZsXQEAAAAAAAIBAQOxRuB6Faz9AzczMzMzMP0B0QX3LnCpAQM3MzMzMDEBAmpmZmZlZQEBmZmZmZmZAQAAAAAAAQEBAMzMzMzOzP0AAAAAAAEA\u002fQMPVARB3cT9AzczMzMyMP0DNzMzMzGxAQAAAAAAAQEBAAAAAAABAP0Diytk7o2VAQDMzMzMzc0BAAAAAAABAQEAzMzMzM3NAQM3MzMzMzD5A21Axzt\u002fEP0Bj7lpCPkBAQM3MzMzMjEBA\u002fYNIhhyPP0CIEcKjjVlAQAAAAAAAgD9AzczMzMzMPkAxem6hK80\u002fQGaIY13cjj1Aj2yumudiQUBxPQrXozBAQAAAAAAAgD5AMzMzMzOzP0BxPQrXo1BAQDMzMzMzc0BAexSuR+G6P0DNzMzMzAxAQM3MzMzMbEBAj8L1KFxvQECF61G4HsU\u002fQI2XbhKDQD9A0a+tn\u002f4NQEDNzMzMzGxAQDMzMzMzc0FA4XoUrkdBQEBmZmZmZuY\u002fQM3MzMzMTEFAMzMzMzNzQUApXI\u002fC9WhAQAAAAAAAwEFAd76fGi9NQECamZmZmXlBQJqZmZmZGT9AKVyPwvXIQUAAAAAAAIBBQGZmZmZmhkFAmpmZmZl5QUAzMzMzM3NBQAAAAAAAgEFAAAAAAACAQUAzMzMzM3NBQA=="},"legendgroup":"","lon":{"dtype":"f8","bdata":"AAAAAACAQUBmZmZmZmZBQGZmZmZmZkFAADyiQnVvQUBmZmZmZqZBQLByaJHtLEFAAAAAAACAQUCSlsrbEW5BQGZmZmZmZkFAAAAAAACAQUBmZmZmZqZBQAAAAAAAgEFAz\u002fdT46WbQUBmZmZmZmZBQGGqmbUULkFAAAAAAABgQUAAAAAAAIBBQM3MzMzMjEFAAAAAAABgQUD2CDVDqn5BQM3MzMzM7EFAAAAAAACAQUCamZmZmZlBQGZmZmZmZkFAZJKRs7CbQUAOvjCZKsBBQDMzMzMz80FAVijS\u002fZy8QUBD5sqg2qZBQDMzMzMzc0FAAAAAAACAQUB9CRUcXlJBQL7e\u002ffFeeUFAsU0qGmt\u002fP0DD9Shcj3JBQAAAAAAAgEFAzczMzMxsQUBoke18P3VBQAAAAAAAwEFAH4XrUbh+QUCamZmZmZlBQM3MzMzMzEFAMzMzMzPzQUCamZmZmblBQGiR7Xw\u002fZUFAX2HB\u002fYBtQUCamZmZmXlBQGZmZmZmJkBAmpmZmZl5QUAAAAAAAIBBQJqZmZmZmT9AMzMzMzMzQEAfhetRuH5BQDMzMzMzc0BAGy\u002fdJAaxQUDNzMzMzMw\u002fQM3MzMzMTEFAmpmZmZmZQEBmZmZmZuY\u002fQAAAAAAAAEBAzczMzMwMQECamZmZmRlAQGZmZmZm5j9AAAAAAADAP0AAAAAAAIA\u002fQA=="},"marker":{"color":{"dtype":"i2","bdata":"djr9JdIiCh3RGhcX1BaxEZsQQRBYCu8JzgkNBwwH\u002fQZCBusFXwU9BTMFIQVkBOUDcAPtAp4CpwElAQkBygCqAGkALwAcABoAGQAWABUACgAKAAcABwAGAAYABAAEAAMAAgACAAIAAgACAAIAAgABAAEAAQABAAEAAQABAAEAAQABAA=="},"coloraxis":"coloraxis","size":{"dtype":"i2","bdata":"djr9JdIiCh3RGhcX1BaxEZsQQRBYCu8JzgkNBwwH\u002fQZCBusFXwU9BTMFIQVkBOUDcAPtAp4CpwElAQkBygCqAGkALwAcABoAGQAWABUACgAKAAcABwAGAAYABAAEAAMAAgACAAIAAgACAAIAAgABAAEAAQABAAEAAQABAAEAAQABAA=="},"sizemode":"area","sizeref":9.35375},"mode":"markers","name":"","showlegend":false,"subplot":"map","type":"scattermap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogr ...

# %% [markdown]
# ## Alerts per city

# %%
alert_city_count = df.city.value_counts().reset_index()
alert_city_count.columns = ["alert_city", "count"]
alert_city_count = alert_city_count.sort_values(by="count", ascending=False)
alert_city_count
# Out:
#            alert_city  count
# 0              Ashdod   2585
# 1            Ashkelon   1041
# 2              Nir Am    731
# 3       Tel Aviv-Yafo    622
# 4       Kiryat Shmona    595
# ...               ...    ...
# 1495       Neveh Haim      1
# 1496  Yearot HaCarmel      1
# 1497            North      1
# 1498            South      1
# 1499             Azuz      1
#
# [1500 rows x 2 columns]

# %% [markdown]
# Reading above result must be careful! The cities like 'Ashdod', "Herzliyya' and 'Tel Aviv' include variety of its districts and nearby localities / industrial zones. Sq space of Ashdod city as per dataset is much larger than Kiryat Shmona, the alerts are sounded in separate districts of large city. However smaller cities liek Kiryat Shmona have alert sounded all over the city. Another example is Nativ haAssara, very close to Gaza border. It's a very small town, however it was constantly shelled during certain periods of war. It's alerts count is comparable to Herzliyaa alerts. However Herzliyya has been shelled from all sides: north, south and east (Lebanon, Iran, Yemen). While shelling in Nativ haAssara is 99% hands of shelling from Gaza.

# %%
# top 50 cities by count of alerts
top50 = alert_city_count.head(50)

top50_cities_graph = px.bar(
    top50,
    x="count",
    y="alert_city",
    orientation="h",
    title="Alerts by the city",
    text="count",
)

top50_cities_graph.update_layout(
    height=1200,
    yaxis_title="City",
    xaxis_title="Alerts count",
    yaxis=dict(autorange="reversed"),
)

top50_cities_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fb76d711-70a6-40e6-b9d9-2b84de3090bf" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fb76d711-70a6-40e6-b9d9-2b84de3090bf")) {                    Plotly.newPlot(                        "fb76d711-70a6-40e6-b9d9-2b84de3090bf",                        [{"hovertemplate":"count=%{text}\u003cbr\u003ealert_city=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"..."},"textposition":"auto","x":{"dtype":"i2","bdata":"GQoRBNsCbgJTAt0B3AHVAbYBtAGdAZoBjAGKAX8BbwFvAWoBZgFJAUgBQwFCAUABOAE2ATQBKAEbAREBDQECAQAB+gD2APMA5gDlAN4A2gDaANkA1wDSANEAzwDNAMsAyADHAA=="},"xaxis":"x","y":["Ashdod","Ashkelon","Nir Am","Tel Aviv-Yafo","Kiryat Shmona","Sderot","Ibim","Herzliyya","Netiv HaAssara","Margaliot","Misgav Am","Akko","Rishon LeZiyyon","Metulla","Haifa","Nachal Oz","Kfar Giladi","Shlomi","Tel Hai","Betzet","Tzfat","Ramat Gan","Zikim","Jerusalem","Manara","Nahariyya","Kissufim","Beersheba","Beit Hillel","Kfar Yuval","Ramla","Ben Shemen","Ma'ayan Baruch","Karmia","Kiryat Bialik","Hanita","Arab al-Aramshe","Zarit","Malkia","Lehman","Rosh HaAyin","Nirim","HaGoshrim","Kerem Shalom","Ramot Naftali","Ya'ara","Shtula","Iftach","Shefayim","Metzuba"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}} ...

# %% [markdown]
# ## Calendar detalization & analysis

# %%
df["alert_date"] = df["alert_datetime"].dt.floor("D")
df["alert_time"] = pd.to_datetime(
    df["alert_datetime"].dt.strftime("%H:%M:%S"),
    format="%H:%M:%S",
)
df.head(200)
# Out:
#       id      alert_datetime alert_type        alert_zone  \
# 0      1 2018-12-26 08:05:08  Red Alert               Dan
# 1      2 2018-12-26 08:05:08  Red Alert               Dan
# 2      3 2018-12-26 08:05:08  Red Alert               Dan
# 3      4 2018-12-26 08:05:08  Red Alert               Dan
# 4      5 2018-12-26 08:05:08  Red Alert               Dan
# ..   ...                 ...        ...               ...
# 195  196 2019-03-15 04:08:40  Red Alert  Gaza Containment
# 196  197 2019-03-15 04:08:40  Red Alert  Gaza Containment
# 197  198 2019-03-15 04:08:40  Red Alert  Gaza Containment
# 198  199 2019-03-15 04:08:40  Red Alert  Gaza Containment
# 199  200 2019-03-15 04:08:40  Red Alert  Gaza Containment
#
#                       locality    region  raw_message_id  \
# 0        Tel Aviv (South West)  Tel Aviv              42
# 1             Tel Aviv (North)  Tel Aviv              42
# 2           Tel Aviv (Central)  Tel Aviv              42
# 3        Tel Aviv (South East)  Tel Aviv              42
# 4                         Azur  Tel Aviv              42
# ..                         ...       ...             ...
# 195              Sapir Academy     South              80
# 196                     Nir Am     South              80
# 197    Sapirim Industrial Park     South              80
# 198                     Sderot     South              80
# 199  Sha'ar Hanegev Industries     South              80
#
#                          city alert_date          alert_time
# 0               Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 1               Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 2               Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 3               Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 4                        Azur 2018-12-26 1900-01-01 08:05:08
# ..                        ...        ...                 ...
# 195                     Sapir 2019-03-15 1900-01-01 04:08:40
# 196                    Nir Am 2019-03-15 1900-01-01 04:08:40
# 197   Sapirim Industrial Park 2019-03-15 1900-01-01 04:08:40
# 198                    Sderot 2019-03-15 1900-01-01 04:08:40
# 199  Shaar Hanegev Industries 2019-03-15 1900-01-01 04:08:40
#
# [200 rows x 10 columns]

# %%
df["month_year"] = df["alert_datetime"].dt.to_period("M")
df.head()
# df.info()
## 8   alert_date      5 non-null       datetime64[ns]
## 9   alert_time      5 non-null       datetime64[ns]
## 10  month_year      5 non-null       period[M]
# Out:
#    id      alert_datetime alert_type alert_zone               locality  \
# 0   1 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South West)
# 1   2 2018-12-26 08:05:08  Red Alert        Dan       Tel Aviv (North)
# 2   3 2018-12-26 08:05:08  Red Alert        Dan     Tel Aviv (Central)
# 3   4 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South East)
# 4   5 2018-12-26 08:05:08  Red Alert        Dan                   Azur
#
#      region  raw_message_id           city alert_date          alert_time  \
# 0  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 1  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 2  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 3  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 4  Tel Aviv              42           Azur 2018-12-26 1900-01-01 08:05:08
#
#   month_year
# 0    2018-12
# 1    2018-12
# 2    2018-12
# 3    2018-12
# 4    2018-12

# %%
# number of alerts by city and date
by_city_day = df.groupby(["city", "alert_date"]).size().reset_index(name="count")
# top 25 worst days and where they happened
top25_days = by_city_day.sort_values(by="count", ascending=False).head(25)
top25_days
# Out:
#                  city alert_date  count
# 2374           Ashdod 2023-10-07    389
# 2367           Ashdod 2019-11-13    311
# 2473         Ashkelon 2023-10-07    218
# 2415           Ashdod 2025-06-13    189
# 2366           Ashdod 2019-11-12    113
# 31012  Netiv HaAssara 2023-10-07     94
# 2416           Ashdod 2025-06-14     85
# 2422           Ashdod 2025-06-22     84
# 2417           Ashdod 2025-06-15     84
# 4329        Beersheba 2023-10-07     76
# 32146          Nir Am 2023-10-07     70
# 25469           Maona 2024-10-29     64
# 2411           Ashdod 2024-10-01     64
# 2441         Ashkelon 2019-05-04     60
# 2403           Ashdod 2023-12-01     58
# 2385           Ashdod 2023-10-20     57
# 2387           Ashdod 2023-10-24     55
# 2373           Ashdod 2023-05-13     54
# 34080          Patish 2023-10-07     50
# 42200           Tkuma 2023-10-07     50
# 38119          Sderot 2023-10-07     46
# 16829            Ibim 2023-10-07     46
# 22878        Kissufim 2023-10-07     45
# 2377           Ashdod 2023-10-11     45
# 27783         Mi'ilya 2024-10-29     43

# %%
top25_days_graph = px.scatter(
    top25_days,
    x="alert_date",
    y="count",
    color="city",
    size="count",
    hover_data={"city": True, "alert_date": True, "count": True},
    title="25 worst days by city",
)

top25_days_graph.update_layout(
    xaxis=dict(tickformat="%b %d %Y"),
    yaxis_title="Number of alerts",
    height=800,
)

top25_days_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ad41101e-d853-429c-b4dd-718ad21a0579" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ad41101e-d853-429c-b4dd-718ad21a0579")) {                    Plotly.newPlot(                        "ad41101e-d853-429c-b4dd-718ad21a0579",                        [{"customdata":[["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"],["Ashdod"]],"hovertemplate":"city=%{customdata[0]}\u003cbr\u003ealert_date=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ashdod","marker":{"color":"#636efa","size":{"dtype":"i2","bdata":"hQE3Ab0AcQBVAFQAVABAADoAOQA3ADYALQA="},"sizemode":"area","sizeref":0.9725,"symbol":"circle"},"mode":"markers","name":"Ashdod","orientation":"v","showlegend":true,"x":["2023-10-07T00:00:00.000000000","2019-11-13T00:00:00.000000000","2025-06-13T00:00:00.000000000","2019-11-12T00:00:00.000000000","2025-06-14T00:00:00.000000000","2025-06-22T00:00:00.000000000","2025-06-15T00:00:00.000000000","2024-10-01T00:00:00.000000000","2023-12-01T00:00:00.000000000","2023-10-20T00:00:00.000000000","2023-10-24T00:00:00.000000000","2023-05-13T00:00:00.000000000","2023-10-11T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"i2","bdata":"hQE3Ab0AcQBVAFQAVABAADoAOQA3ADYALQA="},"yaxis":"y","type":"scatter"},{"customdata":[["Ashkelon"],["Ashkelon"]],"hovertemplate":"city=%{customdata[0]}\u003cbr\u003ealert_date=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ashkelon","marker":{"color":"#EF553B","size":{"dtype":"i2","bdata":"2gA8AA=="},"sizemode":"area","sizeref":0.9725,"symbol":"circle"},"mode":"markers","name":"Ashkelon","orientation":"v","showlegend":true,"x":["2023-10-07T00:00:00.000000000","2019-05-04T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"i2","bdata":"2gA8AA=="},"yaxis":"y","type":"scatter"},{"customdata":[["Netiv HaAssara"]],"hovertemplate":"city=%{customdata[0]}\u003cbr\u003ealert_date=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Netiv HaAssara","marker":{"color":"#00cc96","size":{"dtype":"i1","bdata":"Xg=="},"sizemode":"area","sizeref":0.9725,"symbol":"circle"},"mode":"markers","name":"Netiv HaAssara","orientation":"v","showlegend":true,"x":["2023-10-07T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"i1","bdata":"Xg=="},"yaxis":"y","type":"scatter"},{"customdata":[["Beersheba"]],"hovertemplate":"city=%{customdata[0]}\u003cbr\u003ealert_date=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beersheba","marker":{"color":"#ab63fa","size":{"dtype":"i1","bdata":"TA=="},"sizemode":"area","sizeref":0.9725,"symbol":"circle"},"mode":"markers","name":"Beersheba","orientation":"v","showlegend":true,"x":["2023-10-07T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"i1","bdata":"TA=="},"yaxis":"y","type":"scatter"},{"customdata":[["Nir Am"]],"hovertemplate":"city=%{customdata[0]}\u003cbr\u003ealert_date=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nir Am","marker":{"color":"#FFA15A","size":{"dtype":"i1","bdata":"Rg=="},"sizemode":"area","sizeref":0.9725,"symbol":"circle"},"mode":"markers","name":"Nir Am","orientation":"v","showlegend":true,"x":["2023-10-07T00:00:00.000000000"],"xaxis":"x","y":{"dtype":"i1","bdata":"Rg=="},"yaxis":"y","type":"scatter"},{"customdata":[["Maona"]],"hovertemplate":"city=%{customdata[0]}\u003cbr\u003ealert_date=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maona","marker":{"color":"#19d3f3","size": ...

# %%
# time of the day
# this code cell takes long time to run, even 3 min+

def classify_period(t):
    if pd.isna(t):
        return None

    # Convert Timestamp → time
    if isinstance(t, pd.Timestamp):
        t = t.time()

    if t >= pd.to_datetime("22:00:00").time() or t < pd.to_datetime("06:00:00").time():
        return "night"
    elif t >= pd.to_datetime("06:00:00").time() and t < pd.to_datetime("12:00:00").time():
        return "morning"
    elif t >= pd.to_datetime("12:00:00").time() and t < pd.to_datetime("18:00:00").time():
        return "afternoon"
    else:
        return "evening"


df["period"] = df["alert_time"].apply(classify_period)

df[["alert_datetime", "alert_time", "period"]].head()
# Out:
#        alert_datetime          alert_time   period
# 0 2018-12-26 08:05:08 1900-01-01 08:05:08  morning
# 1 2018-12-26 08:05:08 1900-01-01 08:05:08  morning
# 2 2018-12-26 08:05:08 1900-01-01 08:05:08  morning
# 3 2018-12-26 08:05:08 1900-01-01 08:05:08  morning
# 4 2018-12-26 08:05:08 1900-01-01 08:05:08  morning

# %%
# by_period = df.period.value_counts().reset_index(name='count')
# by_period = by_period.sort_values(by="count", ascending=False)
by_period = df.period.value_counts()
by_period
# Out:
# period
# morning      28459
# evening      26619
# night        23308
# afternoon    21918
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100304 entries, 0 to 100324
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              100304 non-null  int64
#  1   alert_datetime  100304 non-null  datetime64[ns]
#  2   alert_type      100304 non-null  object
#  3   alert_zone      100304 non-null  object
#  4   locality        100304 non-null  object
#  5   region          100304 non-null  object
#  6   raw_message_id  100304 non-null  int64
#  7   city            100304 non-null  object
#  8   alert_date      100304 non-null  datetime64[ns]
#  9   alert_time      100304 non-null  datetime64[ns]
#  10  month_year      100304 non-null  period[M]
#  11  period          100304 non-null  object
# dtypes: datetime64[ns](3), int64(2), object(6), period[M](1)
# memory usage: 9.9+ MB

# %%
labels = by_period.index
sizes = by_period.values


def autopct_threshold(threshold=2):  # do not display label if value < 2%
    def autopct(pct):
        return f"{pct:.1f}%" if pct >= threshold else ""

    return autopct


fig, ax = plt.subplots(figsize=(7, 7))

wedges, texts, autotexts = ax.pie(
    sizes,
    startangle=90,
    autopct=autopct_threshold(2),
    pctdistance=0.8,
    wedgeprops={"width": 0.4, "edgecolor": "white"},
)

ax.set_title("Alert period distribution", fontsize=14)
ax.axis("equal")

ax.legend(
    wedges, labels, title="Alert period", loc="center left", bbox_to_anchor=(1, 0.5)
)

plt.tight_layout()
plt.show()

# %%
by_period_region = (
    df.dropna(subset=["period", "region"])
    .groupby(["period", "region"])
    .size()
    .reset_index(name="count")
)
by_period_region = by_period_region.sort_values(["period", "count"], ascending=[True, False])
by_period_region
# Out:
#        period     region  count
# 3   afternoon      North  10396
# 0   afternoon     Center   4690
# 4   afternoon      South   4468
# 1   afternoon      Haifa    802
# 5   afternoon   Tel Aviv    622
# 6   afternoon       Yosh    542
# 2   afternoon  Jerusalem    398
# 7     evening     Center   9170
# 10    evening      North   6305
# 11    evening      South   5570
# 13    evening       Yosh   2472
# 9     evening  Jerusalem   1556
# 12    evening   Tel Aviv    910
# 8     evening      Haifa    636
# 17    morning      North  11269
# 14    morning     Center   7796
# 18    morning      South   5308
# 20    morning       Yosh   1332
# 15    morning      Haifa   1090
# 16    morning  Jerusalem   1004
# 19    morning   Tel Aviv    660
# 21      night     Center   8898
# 24      night      North   6257
# 25      night      South   3488
# 27      night       Yosh   1730
# 26      night   Tel Aviv   1094
# 23      night  Jerusalem    982
# 22      night      Haifa    859

# %%
period_region_graph = px.treemap(
    by_period_region,
    path=["period", "region"],
    values="count",
    color='period',
    title="Alerts period by region",
)
period_region_graph.update_traces(
    hovertemplate="<b>%{label}</b><br>Alerts: %{value}<extra></extra>"
)  # %{label} and %{value} are Plotly hover placeholders, nice tooltip
period_region_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6d0423cd-93f9-4972-944d-be53d55b5e56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6d0423cd-93f9-4972-944d-be53d55b5e56")) {                    Plotly.newPlot(                        "6d0423cd-93f9-4972-944d-be53d55b5e56",                        [{"branchvalues":"total","customdata":[["afternoon"],["afternoon"],["afternoon"],["afternoon"],["afternoon"],["afternoon"],["afternoon"],["afternoon"],["evening"],["evening"],["evening"],["evening"],["evening"],["evening"],["evening"],["evening"],["morning"],["morning"],["morning"],["morning"],["morning"],["morning"],["morning"],["morning"],["night"],["night"],["night"],["night"],["night"],["night"],["night"],["night"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eAlerts: %{value}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["afternoon\u002fNorth","afternoon\u002fCenter","afternoon\u002fSouth","afternoon\u002fHaifa","afternoon\u002fTel Aviv","afternoon\u002fYosh","afternoon\u002fJerusalem","afternoon","evening","evening\u002fHaifa","evening\u002fTel Aviv","evening\u002fNorth","evening\u002fYosh","evening\u002fSouth","evening\u002fCenter","evening\u002fJerusalem","morning\u002fTel Aviv","morning\u002fJerusalem","morning\u002fCenter","morning\u002fYosh","morning\u002fSouth","morning","morning\u002fNorth","morning\u002fHaifa","night\u002fCenter","night\u002fNorth","night\u002fSouth","night\u002fYosh","night\u002fTel Aviv","night\u002fJerusalem","night\u002fHaifa","night"],"labels":["North","Center","South","Haifa","Tel Aviv","Yosh","Jerusalem","afternoon","evening","Haifa","Tel Aviv","North","Yosh","South","Center","Jerusalem","Tel Aviv","Jerusalem","Center","Yosh","South","morning","North","Haifa","Center","North","South","Yosh","Tel Aviv","Jerusalem","Haifa","night"],"marker":{"colors":["#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#636efa","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#EF553B","#00cc96","#00cc96","#00cc96","#00cc96","#00cc96","#00cc96","#00cc96","#00cc96","#ab63fa","#ab63fa","#ab63fa","#ab63fa","#ab63fa","#ab63fa","#ab63fa","#ab63fa"]},"name":"","parents":["afternoon","afternoon","afternoon","afternoon","afternoon","afternoon","afternoon","","","evening","evening","evening","evening","evening","evening","evening","morning","morning","morning","morning","morning","","morning","morning","night","night","night","night","night","night","night",""],"values":{"dtype":"f8","bdata":"AAAAAABOxEAAAAAAAFKyQAAAAAAAdLFAAAAAAAAQiUAAAAAAAHCDQAAAAAAA8IBAAAAAAADgeEAAAAAAgGfVQAAAAADA\u002ftlAAAAAAADgg0AAAAAAAHCMQAAAAAAAobhAAAAAAABQo0AAAAAAAMK1QAAAAAAA6cFAAAAAAABQmEAAAAAAAKCEQAAAAAAAYI9AAAAAAAB0vkAAAAAAANCUQAAAAAAAvLRAAAAAAMDK20AAAAAAgALGQAAAAAAACJFAAAAAAABhwUAAAAAAAHG4QAAAAAAAQKtAAAAAAAAIm0AAAAAAABiRQAAAAAAAsI5AAAAAAADYikAAAAAAAMPWQA=="},"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555 ...

# %% [markdown]
# ### Who suffered from most night alerts?

# %%
df_night = df[df['period'] == 'night']
df_night.head()
night_city_count = df_night.city.value_counts().reset_index(name='count')
night_city_count = night_city_count.sort_values(by="count", ascending=False)
top_n = 20
night_city_count = night_city_count.head(top_n)
night_city_count["share"] = (
    night_city_count["count"] / night_city_count["count"].sum() * 100)
night_city_count
# share shown within all 20 cities total, not share of night alerts within each city total alerts
# Out:
#                city  count  share
# 0            Ashdod    277  13.51
# 1     Tel Aviv-Yafo    197   9.61
# 2         Herzliyya    146   7.12
# 3          Ashkelon    137   6.68
# 4   Rishon LeZiyyon    117   5.70
# 5        Ben Shemen    112   5.46
# 6            Nir Am    110   5.36
# 7         Ramat Gan    105   5.12
# 8             Ramla    100   4.88
# 9             Haifa     81   3.95
# 10      Rosh HaAyin     79   3.85
# 11             Ibim     77   3.75
# 12           Sderot     77   3.75
# 13         Shefayim     69   3.36
# 14        Beersheba     69   3.36
# 15    Kiryat Shmona     63   3.07
# 16         Yashresh     60   2.93
# 17          Tzafria     59   2.88
# 18              Lod     58   2.83
# 19    Be'er Ya'akov     58   2.83

# %%
night_alerts_graph = px.funnel(
    night_city_count,
    x="count",
    y="city",
    text=night_city_count["share"].round(1).astype(str) + "%",
    title="Cities with the Most Night Alerts",
)

night_alerts_graph.update_traces(
    texttemplate="%{text} • %{value:,} alerts",
    textposition="auto",
    textfont=dict(
        size=18,
        color="white",
    ),
)

night_alerts_graph.update_layout(
    height=650,
    yaxis=dict(categoryorder="total descending"),
    uniformtext_minsize=16,
)

night_alerts_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="75140ca9-e090-4707-916b-3c7e2625c624" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("75140ca9-e090-4707-916b-3c7e2625c624")) {                    Plotly.newPlot(                        "75140ca9-e090-4707-916b-3c7e2625c624",                        [{"hovertemplate":"count=%{x}\u003cbr\u003ecity=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","orientation":"h","showlegend":false,"text":["13.5%","9.6%","7.1%","6.7%","5.7%","5.5%","5.4%","5.1%","4.9%","3.9%","3.9%","3.8%","3.8%","3.4%","3.4%","3.1%","2.9%","2.9%","2.8%","2.8%"],"x":{"dtype":"i2","bdata":"FQHFAJIAiQB1AHAAbgBpAGQAUQBPAE0ATQBFAEUAPwA8ADsAOgA6AA=="},"xaxis":"x","y":["Ashdod","Tel Aviv-Yafo","Herzliyya","Ashkelon","Rishon LeZiyyon","Ben Shemen","Nir Am","Ramat Gan","Ramla","Haifa","Rosh HaAyin","Ibim","Sderot","Shefayim","Beersheba","Kiryat Shmona","Yashresh","Tzafria","Lod","Be'er Ya'akov"],"yaxis":"y","type":"funnel","textfont":{"color":"white","size":18},"textposition":"auto","texttemplate":"%{text} • %{value:,} alerts"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern" ...

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df["alert_datetime"].dt.hour, bins=24, kde=False, color="skyblue")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Alerts")
plt.title("Distribution of Alerts by Hour")
plt.xticks(range(0, 24))
plt.show()

# %%
plt.figure(figsize=(12, 6))
alert_times_in_hours = (
    df["alert_datetime"].dt.hour + df["alert_datetime"].dt.minute / 60
)
sns.kdeplot(alert_times_in_hours, bw_adjust=0.5, fill=True, color="purple")
plt.xlabel("Hour of Day (with minutes)")
plt.ylabel("Density")
plt.title("Kernel Density of Alert Times During the Day")
plt.xlim(0, 24)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(
    df, x=df["alert_datetime"].dt.hour, hue="period", multiple="stack", bins=24
)
plt.xlabel("Hour of Day")
plt.ylabel("Number of Alerts")
plt.title("Alerts Distribution by Period of Day")
plt.show()

# %% [markdown]
# ## Timeline

# %%
by_month_year = df.groupby("month_year").size().reset_index(name="count")
by_month_year = by_month_year.sort_values("month_year")
by_month_year["month_year"] = by_month_year["month_year"].dt.to_timestamp()
by_month_year
# Out:
#    month_year  count
# 0  2018-12-01     60
# 1  2019-01-01     32
# 2  2019-02-01     35
# 3  2019-03-01    327
# 4  2019-04-01      1
# ..        ...    ...
# 70 2025-09-01   1987
# 71 2025-10-01    239
# 72 2025-11-01      8
# 73 2025-12-01      5
# 74 2026-01-01      1
#
# [75 rows x 2 columns]

# %%
by_month_year_graph = px.line(
    by_month_year,
    x="month_year",
    y="count",
    markers=True,
    title="Alerts per Month",
    labels={
        "month_year": "Year & Month",
        "count": "Alerts count",
    },
)

by_month_year_graph.update_traces(
    hovertemplate="Month: %{x|%Y-%m}<br>Alerts: %{y:,}<extra></extra>"
)

by_month_year_graph.update_layout(height=500, xaxis=dict(tickformat="%Y-%m"))

by_month_year_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="32e79651-3736-4db9-8da5-44fe14cc6806" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("32e79651-3736-4db9-8da5-44fe14cc6806")) {                    Plotly.newPlot(                        "32e79651-3736-4db9-8da5-44fe14cc6806",                        [{"hovertemplate":"Month: %{x|%Y-%m}\u003cbr\u003eAlerts: %{y:,}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-03-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2022-02-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00","2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00","2025-08-01T00:00:00","2025-09-01T00:00:00","2025-10-01T00:00:00","2025-11-01T00:00:00","2025-12-01T00:00:00","2026-01-01T00:00:00"],"xaxis":"x","y":{"dtype":"i4","bdata":"..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar": ...

# %%
df.head()
# Out:
#    id      alert_datetime alert_type alert_zone               locality  \
# 0   1 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South West)
# 1   2 2018-12-26 08:05:08  Red Alert        Dan       Tel Aviv (North)
# 2   3 2018-12-26 08:05:08  Red Alert        Dan     Tel Aviv (Central)
# 3   4 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South East)
# 4   5 2018-12-26 08:05:08  Red Alert        Dan                   Azur
#
#      region  raw_message_id           city alert_date          alert_time  \
# 0  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 1  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 2  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 3  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 4  Tel Aviv              42           Azur 2018-12-26 1900-01-01 08:05:08
#
#   month_year   period
# 0    2018-12  morning
# 1    2018-12  morning
# 2    2018-12  morning
# 3    2018-12  morning
# 4    2018-12  morning

# %%
df["year_clean"] = df["alert_datetime"].dt.year

df_7years = df[(df["year_clean"] >= 2019) & (df["year_clean"] <= 2025)]

by_year_period = (
    df_7years.groupby(["year_clean", "period"]).size().reset_index(name="count")
)
by_year_period["share"] = by_year_period["count"] / by_year_period.groupby(
    "year_clean"
)["count"].transform("sum")

by_year_period = by_year_period.sort_values(by="year_clean")

period_change_graph = px.bar(
    by_year_period,
    x="share",
    y="year_clean",
    color="period",
    orientation="h",
    title="Share of alerts by period per year (2019–2025)",
    labels={
        "year_clean": "Year",
        "share": "Share of alerts",
        "period": "Period of day",
    },
    color_discrete_map={
        "night": "darkorchid",
        "morning": "mediumseagreen",
        "afternoon": "gold",
        "evening": "darkgrey",
    },
)
period_change_graph.update_traces(
    hovertemplate=(
        "Year: %{x}<br>" "Period: %{legendgroup}<br>" "Share: %{y:.1%}<extra></extra>"
    )
)
period_change_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="bf02db01-326c-4f5c-84a9-a889ab2432cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bf02db01-326c-4f5c-84a9-a889ab2432cc")) {                    Plotly.newPlot(                        "bf02db01-326c-4f5c-84a9-a889ab2432cc",                        [{"hovertemplate":"Year: %{x}\u003cbr\u003ePeriod: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"afternoon","marker":{"color":"gold","pattern":{"shape":""}},"name":"afternoon","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"Tysqc840zz9ikTLwdGveP59aWOmphcU\u002f3pA35A150z\u002fCcU0fJOfUP9QkGbhmMdU\u002fo66oK+qKuj8="},"xaxis":"x","y":{"dtype":"i4","bdata":"4wcAAOQHAADlBwAA5gcAAOcHAADoBwAA6QcAAA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Year: %{x}\u003cbr\u003ePeriod: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"evening","marker":{"color":"darkgrey","pattern":{"shape":""}},"name":"evening","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"wIT62KoE0j+u+WGRMvDUPw6afNmgydc\u002fhT1hT9gT1j8aIq7gpuzPP\u002feNyE8+ctA\u002fiOhvadZt0T8="},"xaxis":"x","y":{"dtype":"i4","bdata":"4wcAAOQHAADlBwAA5gcAAOcHAADoBwAA6QcAAA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Year: %{x}\u003cbr\u003ePeriod: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"morning","marker":{"color":"mediumseagreen","pattern":{"shape":""}},"name":"morning","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"DeQuIAsf1D+6NT8sUgauP8NKTy2s9NQ\u002fbUlb0pa0xT92cMYrnpTXP84Zneda6NA\u002fJ8C7gLRM0T8="},"xaxis":"x","y":{"dtype":"i4","bdata":"4wcAAOQHAADlBwAA5gcAAOcHAADoBwAA6QcAAA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Year: %{x}\u003cbr\u003ePeriod: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"night","marker":{"color":"darkorchid","pattern":{"shape":""}},"name":"night","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"GAODmsWDxD9yHMdxHMfBP8HbDwm8\u002fcA\u002fzBlzxpwxxz\u002fbZagkUm+sP81mAiEA6MI\u002fqSvqirqi1j8="},"xaxis":"x","y":{"dtype":"i4","bdata":"4wcAAOQHAADlBwAA5gcAAOcHAADoBwAA6QcAAA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar ...

# %%
region_alert_type = (
    df.groupby(["region", "alert_type"]).size().reset_index(name="count")
)
region_alert_type["share"] = region_alert_type["count"] / region_alert_type.groupby(
    "region"
)["count"].transform("sum")

region_alert_type_graph = px.bar(
    region_alert_type,
    x="share",
    y="region",
    color="alert_type",
    orientation="h",
    title="Share of alerts by type per region",
    labels={
        "region": "Region",
        "share": "Share of alerts",
        "alert_type": "Type",
    },
    color_discrete_map={
        "night": "darkorchid",
        "morning": "mediumseagreen",
        "afternoon": "gold",
        "evening": "darkgrey",
    },
)
region_alert_type_graph.update_traces(
    hovertemplate=(
        "Region: %{x}<br>"
        "Alert type: %{legendgroup}<br>"
        "Share: %{y:.1%}<extra></extra>"
    )
)

region_alert_type_graph.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="8fd3e93a-f575-4749-94a5-8fb78d9c6f33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8fd3e93a-f575-4749-94a5-8fb78d9c6f33")) {                    Plotly.newPlot(                        "8fd3e93a-f575-4749-94a5-8fb78d9c6f33",                        [{"hovertemplate":"Region: %{x}\u003cbr\u003eAlert type: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"An alert","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"An alert","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"XrxTx80oAT\u002fv+ONOWtYLPw=="},"xaxis":"x","y":["Center","South"],"yaxis":"y","type":"bar"},{"hovertemplate":"Region: %{x}\u003cbr\u003eAlert type: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Earthquake","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Earthquake","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"6jM+gOdNMz\u002f+efaZcVOQP7\u002fy6jgtojA\u002fT6G79kz6jT\u002fv+ONOWtY7P9XSs3v+hmE\u002f"},"xaxis":"x","y":["Center","Haifa","Jerusalem","North","South","Yosh"],"yaxis":"y","type":"bar"},{"hovertemplate":"Region: %{x}\u003cbr\u003eAlert type: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Interception pieces","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Interception pieces","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"XrxTx80oAT8="},"xaxis":"x","y":["Center"],"yaxis":"y","type":"bar"},{"hovertemplate":"Region: %{x}\u003cbr\u003eAlert type: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red Alert","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Red Alert","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"6R0DHiXd7z\u002fzhFMdtAPtP+WnCi\u002fD+e8\u002f+p6jRL296D+H5uC39CbvP8VnslUO7O8\u002fXmxT\u002fzsk7z8="},"xaxis":"x","y":["Center","Haifa","Jerusalem","North","South","Tel Aviv","Yosh"],"yaxis":"y","type":"bar"},{"hovertemplate":"Region: %{x}\u003cbr\u003eAlert type: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Terrorist Infiltration","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Terrorist Infiltration","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"XrxTx80oIT\u002f00rsxalkzP1WUWM9yzio\u002f7\u002fjjTlrWOz\u002f7ssbrBz+GPw=="},"xaxis":"x","y":["Center","Haifa","North","South","Yosh"],"yaxis":"y","type":"bar"},{"hovertemplate":"Region: %{x}\u003cbr\u003eAlert type: %{legendgroup}\u003cbr\u003eShare: %{y:.1%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unrecognized Aircraft","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Unrecognized Aircraft","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"eXYqwlHVbj8TfrREKbqzP7\u002fy6jgtokA\u002f3vNRgbIiyz9ZnUQEyzSaP5Y6mE2q8WM\u002f40BxoDhQjD8="},"xaxis":"x","y":["Center","Haifa","Jerusalem","North","South","Tel Aviv","Yosh"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choro ...

# %%
# minute of the hour
def classify_minute_bucket(t):
    if pd.isna(t):
        return None

    # if Timestamp -> extract minute
    if isinstance(t, pd.Timestamp):
        minute = t.minute
    else:
        minute = t.minute  # datetime.time also has .minute

    if minute <= 5 or minute >= 55:
        return "00-minute"
    elif 25 <= minute <= 35:
        return "30-minute"
    else:
        return "other"

df["minute_bucket"] = df["alert_time"].apply(classify_minute_bucket)
df.head()
# Out:
#    id      alert_datetime alert_type alert_zone               locality  \
# 0   1 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South West)
# 1   2 2018-12-26 08:05:08  Red Alert        Dan       Tel Aviv (North)
# 2   3 2018-12-26 08:05:08  Red Alert        Dan     Tel Aviv (Central)
# 3   4 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South East)
# 4   5 2018-12-26 08:05:08  Red Alert        Dan                   Azur
#
#      region  raw_message_id           city alert_date          alert_time  \
# 0  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 1  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 2  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 3  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 4  Tel Aviv              42           Azur 2018-12-26 1900-01-01 08:05:08
#
#   month_year   period  year_clean minute_bucket
# 0    2018-12  morning        2018     00-minute
# 1    2018-12  morning        2018     00-minute
# 2    2018-12  morning        2018     00-minute
# 3    2018-12  morning        2018     00-minute
# 4    2018-12  morning        2018     00-minute

# %%
by_region_minute = (
    df.groupby(["region", "minute_bucket"]).size().reset_index(name="count")
)

by_region_minute["share"] = by_region_minute["count"] / by_region_minute.groupby(
    "region")["count"].transform("sum")
by_region_minute
# Out:
#        region minute_bucket  count  share
# 0      Center     00-minute   4622   0.15
# 1      Center     30-minute   4463   0.15
# 2      Center         other  21469   0.70
# 3       Haifa     00-minute    525   0.16
# 4       Haifa     30-minute    571   0.17
# 5       Haifa         other   2291   0.68
# 6   Jerusalem     00-minute    591   0.15
# 7   Jerusalem     30-minute    799   0.20
# 8   Jerusalem         other   2550   0.65
# 9       North     00-minute   5981   0.17
# 10      North     30-minute   5442   0.16
# 11      North         other  22804   0.67
# 12      South     00-minute   3862   0.21
# 13      South     30-minute   3035   0.16
# 14      South         other  11937   0.63
# 15   Tel Aviv     00-minute    702   0.21
# 16   Tel Aviv     30-minute    496   0.15
# 17   Tel Aviv         other   2088   0.64
# 18       Yosh     00-minute    400   0.07
# 19       Yosh     30-minute    871   0.14
# 20       Yosh         other   4805   0.79

# %%
df.head()
# Out:
#    id      alert_datetime alert_type alert_zone               locality  \
# 0   1 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South West)
# 1   2 2018-12-26 08:05:08  Red Alert        Dan       Tel Aviv (North)
# 2   3 2018-12-26 08:05:08  Red Alert        Dan     Tel Aviv (Central)
# 3   4 2018-12-26 08:05:08  Red Alert        Dan  Tel Aviv (South East)
# 4   5 2018-12-26 08:05:08  Red Alert        Dan                   Azur
#
#      region  raw_message_id           city alert_date          alert_time  \
# 0  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 1  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 2  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 3  Tel Aviv              42  Tel Aviv-Yafo 2018-12-26 1900-01-01 08:05:08
# 4  Tel Aviv              42           Azur 2018-12-26 1900-01-01 08:05:08
#
#   month_year   period  year_clean minute_bucket
# 0    2018-12  morning        2018     00-minute
# 1    2018-12  morning        2018     00-minute
# 2    2018-12  morning        2018     00-minute
# 3    2018-12  morning        2018     00-minute
# 4    2018-12  morning        2018     00-minute

# %%
by_year_minute = (
    df.groupby(["year_clean", "minute_bucket"]).size().reset_index(name="count")
)

by_year_minute["share"] = by_year_minute["count"] / by_year_minute.groupby(
    "year_clean"
)["count"].transform("sum")
by_year_minute
# Out:
#     year_clean minute_bucket  count  share
# 0         2018     00-minute     60   1.00
# 1         2019     00-minute   1047   0.22
# 2         2019     30-minute    428   0.09
# 3         2019         other   3242   0.69
# 4         2020     00-minute     56   0.17
# 5         2020     30-minute     44   0.14
# 6         2020         other    224   0.69
# 7         2021     00-minute     16   0.14
# 8         2021     30-minute     26   0.23
# 9         2021         other     71   0.63
# 10        2022     00-minute    335   0.32
# 11        2022     30-minute    101   0.10
# 12        2022         other    596   0.58
# 13        2023     00-minute   5081   0.34
# 14        2023     30-minute   3770   0.25
# 15        2023         other   5968   0.40
# 16        2024     00-minute   5756   0.18
# 17        2024     30-minute   5834   0.18
# 18        2024         other  20176   0.64
# 19        2025     00-minute   4331   0.09
# 20        2025     30-minute   5474   0.12
# 21        2025         other  37667   0.79
# 22        2026     00-minute      1   1.00

# %%
plot_df = by_region_minute.pivot(
    index="region", columns="minute_bucket", values="share"
).fillna(0)
plot_df = plot_df[["00-minute", "30-minute", "other"]]

plot_df
# Out:
# minute_bucket  00-minute  30-minute  other
# region
# Center              0.15       0.15   0.70
# Haifa               0.16       0.17   0.68
# Jerusalem           0.15       0.20   0.65
# North               0.17       0.16   0.67
# South               0.21       0.16   0.63
# Tel Aviv            0.21       0.15   0.64
# Yosh                0.07       0.14   0.79

# %%
fig, ax = plt.subplots(figsize=(10, 6))

plot_df.plot(kind="barh", stacked=True, ax=ax)

ax.set_title("Share of alerts by minute pattern (00 / 30 / other)")
ax.set_xlabel("Share of alerts")
ax.set_ylabel("Region")

ax.legend(title="Minute bucket", bbox_to_anchor=(1.02, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %% [markdown]
# From first glance it may seem that there is no significance in alert time, however! The buckets were set with 5 minute variance each direction. Therefore:
# 2 buckets = 10 * 2 = 20 minutes. 20 minutes in each hour is 33% of whole day time. Eyeballing the graph, we can say that in all regions except Yosh, appr 32% of alerts
# happen during 33% of time. In other words, every 3rd alert happens durin 00th minute or 30th minute. And other 2 - during the rest of time (XX:06 - XX:25 and XX:35-XX:55) which is more spread. Tel-Aviv area is visibly more threatened during the 00th miute, while Jerusalem area - during the 30th minute.

# %% [markdown]
# ## Statistical hypothesis: are the minute-buckets distribution real or just random? (statistical uncertainty)

# %% [markdown]
# Confidence interval: CI=p±1.96⋅np(1−p)​ (here p is the share we got before and n is the total alerts in region)

# %%
# confidence intervals per region × bucket
region_totals = df.groupby("region").size().rename("n")

by_region_minute = by_region_minute.merge(region_totals, on="region")

by_region_minute["ci_low"] = by_region_minute["share"] - 1.96 * np.sqrt(
    (by_region_minute["share"] * (1 - by_region_minute["share"]))
    / by_region_minute["n"]
)

by_region_minute["ci_high"] = by_region_minute["share"] + 1.96 * np.sqrt(
    (by_region_minute["share"] * (1 - by_region_minute["share"]))
    / by_region_minute["n"]
)
by_region_minute.head()
# Narrow CI → strong evidence
# Wide CI → region has few alerts → don’t overinterpret
# Out:
#    region minute_bucket  count  share      n  ci_low  ci_high
# 0  Center     00-minute   4622   0.15  30554    0.15     0.16
# 1  Center     30-minute   4463   0.15  30554    0.14     0.15
# 2  Center         other  21469   0.70  30554    0.70     0.71
# 3   Haifa     00-minute    525   0.16   3387    0.14     0.17
# 4   Haifa     30-minute    571   0.17   3387    0.16     0.18

# %% [markdown]
# CHi squared test: Are the alerts really more likely at 00 or 30 min or not? (other)
# * (H₀): Minute buckets are uniformly distributed
# * (H1): Minute buckets are distributed unevenly and YES they are more likely to happen at 00 / 30

# %%
observed = df["minute_bucket"].value_counts().sort_index()
chi2, p_value = chisquare(observed)
print(f"Chi2: {chi2:.10f}, p-value: {p_value:.50f}")
print(f"Chi2: {chi2:.10f}, p-value: {p_value:.5e}")
# p-value: 0.0e+00 - super tiny
# Out:
# Chi2: 53442.9478983889, p-value: 0.00000000000000000000000000000000000000000000000000
# Chi2: 53442.9478983889, p-value: 0.00000e+00

# %% [markdown]
# Interpretation:
# p < 0.001 → extremely strong evidence -> clustering is real

# %%
# per region
results = []

for region, g in df.groupby("region"):
    counts = g["minute_bucket"].value_counts()

    if len(counts) < 3:
        continue  # skip regions with missing buckets

    chi2, p = chisquare(counts)

    results.append({"region": region, "chi2": chi2, "p_value": p})

chi2_results = pd.DataFrame(results).sort_values("p_value")
chi2_results["p_value_sci"] = chi2_results["p_value"].apply(lambda x: f"{x:.5e}")
chi2_results
# Out:
#       region      chi2  p_value   p_value_sci
# 0     Center 18,755.34     0.00   0.00000e+00
# 1      Haifa  1,794.88     0.00   0.00000e+00
# 2  Jerusalem  1,763.18     0.00   0.00000e+00
# 3      North 17,084.26     0.00   0.00000e+00
# 4      South  7,706.02     0.00   0.00000e+00
# 6       Yosh  5,777.19     0.00   0.00000e+00
# 5   Tel Aviv  1,368.81     0.00  5.85582e-298

# %% [markdown]
# * All regions have very small p-values which means there is a very strong timing structure = alerts are LESS random in time.
# * Center, North, and South have very high chi-squared statistics => their minute distributions are very concentrated around minutes bucket groups that I defined (0 & 30min).

# %% [markdown]
# * Result: H0 rejected.
# * Alert timestamps are not uniformly distributed within the hour.
# * There is statistically significant clustering around 00 and 30 minutes, consistent across multiple regions.

# %% [markdown]
# ## Geo distribution

# %%
by_region_zone = df.groupby(["region", "alert_zone"]).size().reset_index(name="count")
by_region_zone.head()
# Out:
#    region          alert_zone  count
# 0  Center              Ashdod    154
# 1  Center        Beit Shemesh      5
# 2  Center      Center Galilee    333
# 3  Center        Center Negev     27
# 4  Center  Confrontation Line    215

# %%
# Make sure by_region_zone exists and has all columns you need
# Example: by_region_zone = df.groupby(["region", "alert_zone"]).size().reset_index(name="count")

# Export to CSV
by_region_zone.to_csv("by_region_zone_export.csv", index=False, encoding="utf-8-sig")

print("Exported all rows to 'by_region_zone_export.csv'.")
# Out:
# Exported all rows to 'by_region_zone_export.csv'.

# %% [markdown]
# THe region was assigned as per locality. During the above cell analysis, I observed taht some regions are definitely not corresponding to the zone. Example:
# * region	alert_zone
# * Center	Center Galilee,
# * Center	Gaza Containment,
# * Jerusalem	South Golan,
# * North	Dead Sea,
# * North	South Negev,
# * South	South Golan,
#
# Manually changing all i.e. Center Gallillee to North may result in irrepairable mistake. After deeper analysis of regions VS zones and localities corresponding to those regions, I came to conclusion that the mistakes are due to the name duplication / translation of localities names. There are many mistakes however their share in the total count of rows is insignificant.

# %%
geo_sunburst = px.sunburst(
    by_region_zone,
    path=["region", "alert_zone"],
    values="count",
    color="count",
    color_continuous_scale="Viridis",
    width=1200,
    height=1000,
    title="Sunburst of Missions by year and country",
)

geo_sunburst.update_traces(
    sort=False, selector=dict(type="sunburst")
)

geo_sunburst.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c61b8f8b-1756-4ff6-aa2a-1b1fbb96346a" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c61b8f8b-1756-4ff6-aa2a-1b1fbb96346a")) {                    Plotly.newPlot(                        "c61b8f8b-1756-4ff6-aa2a-1b1fbb96346a",                        [{"branchvalues":"total","customdata":{"dtype":"f8","bdata":"\u002fAAAAAAAA8D8AAAAAAIB6QAAAAAAAaIZAAAAAAACklEAAAAAAAEBgQAAAAAAAACZAAAAAAACAc0AAAAAAAAAAQAAAAAAAgEFAAAAAAADgYUAAAAAAAEBtQAAAAAAAAPA\u002fAAAAAACATEAAAAAAAAAUQAAAAAAAgIhAAAAAAAByqEAAAAAAAAA2QAAAAAAAuIZAAAAAAAAAU0AAAAAAABaiQAAAAAAAAPA\\u002fAAAAAAAANUAAAAAAAAAAQAAAAAAAAPA\...","shape":"126, 1"},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003ecount=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Center\u002fAshdod","Center\u002fBeit Shemesh","Center\u002fCenter Galilee","Center\u002fCenter Negev","Center\u002fConfrontation Line","Center\u002fDan","Center\u002fGaza Containment","Center\u002fHaAmakim","Center\u002fHaShfela","Center\u002fHefer","Center\u002fLakhish","Center\u002fMenashe","Center\u002fSharon","Center\u002fShfela","Center\u002fShfelat Yehuda","Center\u002fShomron","Center\u002fSouthern Shfela","Center\u002fWadi Ara","Center\u002fWest Lakhish","Center\u002fYarkon","Center\u002fYarkon Modi'in","Center\u002fYehuda","Center\u002fיהוד מונוסון","Center\u002fכרכור","Center\u002fמודיעין מכבים רעות","Center\u002fמיני ישראל","Center\u002fנאות קדומים","Center\u002fשוהם","Haifa\u002fHaAmakim","Haifa\u002fHaCarmel","Haifa\u002fHaMifratz","Haifa\u002fHaShfela","Haifa\u002fHof HaCarmel","Haifa\u002fMenashe","Haifa\u002fPardes Hana","Haifa\u002fSharon","Haifa\u002fUpper Galilee","Haifa\u002fWadi Ara","Haifa\u002fYe'arut HaCarmel (Carmel Forest)","Haifa\u002fYehuda","Jerusalem\u002fBeit Shemesh","Jerusalem\u002fJerusalem","Jerusalem\u002fShfelat Yehuda","Jerusalem\u002fSouth Golan","North\u002fBeit She'an Valley","North\u002fBika'a","North\u002fCenter Galilee","North\u002fCenter Negev Beer Sheva","North\u002fConfrontation Line","North\u002fDead Sea","North\u002fGolan","North\u002fHaAmakim","North\u002fHaCarmel","North\u002fHaMifratz","North\u002fHaShfela","North\u002fHaifa","North\u002fHof HaCarmel","North\u002fKfar Yehoshua Train Station","North\u002fLev HaChula","North\u002fLower Galilee","North\u002fMenashe","North\u002fMilouot Industrial North","North\u002fNorth Golan","North\u002fSharon","North\u002fShomron","North\u002fSouth Golan","North\u002fSouth Negev","North\u002fUpper Galilee","North\u002fWadi Ara","North\u002fYarkon","North\u002fYe'arut HaCarmel (Carmel Forest)","North\u002fYehuda","North\u002fZefat","North\u002fכפר נחום","North\u002fקריית שמונה","South\u002fArabah","South\u002fArava","South\u002fAshdod","South\u002fBika'a","South\u002fCenter Negev","South\u002fCenter Negev \u002f Gaza Containment","South\u002fCenter Negev Beer Sheva","South\u002fConfrontation Line","South\u002fDead Sea","South\u002fEilat","South\u002fGaza Containment","South\u002fGaza Envelope","South\u002fHaAm ...

# %% [markdown]
# ## Largest cities: alerts count

# %%
largest_cities = [
    "Jerusalem",
    "Tel Aviv-Yafo",
    "Haifa",
    "Bnei Brak",
    "Ashdod",
    "Beersheba",
]

largest_cities_df = df[df["city"].isin(largest_cities)]
largest_cities_count = (
    largest_cities_df.groupby(["month_year", "city"])
    .size()
    .reset_index(name="count")
    .sort_values("month_year")
)

largest_cities_count
# Out:
#    month_year           city  count
# 0     2018-12      Bnei Brak      1
# 1     2018-12  Tel Aviv-Yafo      4
# 2     2019-02      Jerusalem      1
# 3     2019-03      Bnei Brak      2
# 4     2019-03  Tel Aviv-Yafo      6
# ..        ...            ...    ...
# 89    2025-09         Ashdod      9
# 90    2025-09      Bnei Brak      4
# 91    2025-09      Jerusalem     22
# 92    2025-09  Tel Aviv-Yafo     19
# 93    2025-10         Ashdod     20
#
# [94 rows x 3 columns]

# %%
## may need to run the cell twice, on first run get an error, just rerun

# Separating Ashdod due to its scale being far larger than other cities
ashdod_df = largest_cities_count[largest_cities_count["city"] == "Ashdod"]
other_cities_df = largest_cities_count[largest_cities_count["city"] != "Ashdod"]

# # Converting to timestamp like "2023-10" otherwise wont work as type of 'month_year' ='Period'
largest_cities_count["month_year_ts"] = largest_cities_count[
    "month_year"
].dt.to_timestamp()


large_cities_graph = go.Figure()

# Add all other cities to primary y-axis
for city in other_cities_df["city"].unique():
    city_df = other_cities_df[other_cities_df["city"] == city].sort_values(
        "month_year_ts"
    )
    large_cities_graph.add_trace(
        go.Scatter(
            x=city_df["month_year_ts"],
            y=city_df["count"],
            name=city,
            mode="lines+markers",
            yaxis="y1",
        )
    )

# Add Ashdod to secondary y-axis
ashdod_df = ashdod_df.sort_values("month_year_ts")
large_cities_graph.add_trace(
    go.Scatter(
        x=ashdod_df["month_year_ts"],
        y=ashdod_df["count"],
        name="Ashdod",
        mode="lines+markers",  # determines how the graph looks, mine - line plot with points
        yaxis="y2",
        line=dict(color="red", width=2, dash="dot"),
    )
)

# Layout
large_cities_graph.update_layout(
    title="Timeline of alert counts: Ashdod vs Other Largest Cities",
    xaxis=dict(title="Month", type="date"),
    yaxis=dict(title="Largest Cities Count, except Ashdod area (primary)", side="left"),
    yaxis2=dict(
        title="Ashdod area Count (secondary)",
        overlaying="y",
        side="right",
    ),
    height=600,
    legend=dict(
        orientation="h",  # horizontal legend
        yanchor="bottom",
        y=1.02,  # place above the plot
        xanchor="center",
        x=0.5,  # center it
    ),
)


large_cities_graph.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15784\2518871329.py in ?()
#      13 large_cities_graph = go.Figure()
#      14
#      15 # Add all other cities to primary y-axis
#      16 for city in other_cities_df["city"].unique():
# ---> 17     city_df = other_cities_df[other_cities_df["city"] == city].sort_values(
#      18         "month_year_ts"
#      19     )
#      20     large_cities_graph.add_trace(
#
# c:\Users\PC\Desktop\tech_stuff\Studying\Python\AppBrewery UDemy bootcamp\projects_irenka\professional_portfolio\99_cumta_db_DA\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7207             )
#    7208         elif len(by):
#    7209             # len(by) == 1
#    7210
# -> 7211             k = self._get_label_or_level_values(by[0], axis=axis)
#    7212
#    7213             # need to rewrap column in Series to apply key function
#    7214             if key is not None:
#
# c:\Users\PC\Desktop\tech_stuff\Studying\Python\AppBrewery UDemy bootcamp\projects_irenka\professional_portfolio\99_cumta_db_DA\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'month_year_ts'

# %% [markdown]
# ## Analysis / conclusions
# * North region received highest count of alerts during the analyzed period (Dec 26, 2018-Dec 27, 2025).
# * Vast majority of Terrorist infiltrations took place in Yosh region.
# * 21.2% of all alerts in the North are Unrecognized aircraft alerts (& Haifa area - 7.8%). Rest of areas it's below 3%.
# * Ashdod high numbers are mostly due to the fact that the city covers vast areas around it, including many industrial parks and districts.
# * When analyzing, city size must be taken into consideration, as the alerts shot on large area disturb much larger amount of people, while multiple attacks onto a small town means it's targeted due to some reason (location, probably).
# * The worst days were seen in Ashdod and Ashkelon, with amount of alerts from 113 to 389 PER SINGLE DAY! Ashdod was targeted during all 3 peaks of the wars: NOv 2019, Oct 2023, Jun 2025. 389 alerts per day means alert each 3.7 minutes.
# * Period-wise, it's more or less same, with slightly more alerts during the morning hours and over 23% of daily alerts during the nighttime. Most night alerts are sounded in the Center region. Among 20 top cities who received night alerts, 13.5% of them happened in Ashdod area and 9.6% in Tel-Aviv area.
# * Most alerts sounded between 7 and 8 AM, 6 and 7 PM and 8 and 9 PM.
# * June 2025 marked the highest count of alerts (almost 34K). However amount of rockets was not as high as any other period. It's due to the fact that the rockets used in June 2025 by Iran were ballistic (they have a very large and wide area of damage in case of hit, therefore alerts sounded in multiple zones simultaneously)
# * There is very clear change in the period of alert from year to year: 2020 (only 20% of alerts happened during the morning and night). In 2023 most alerts happened in the morning, especially the morning of Oct 7 and only 5% at night. However in 2025 35% of alerts happened at night, which was strong psycological pressure on the population of most regions.
# * Statistical research confirmed my hypothethis that large portion of alerts happened at specific time, as if the terrorists set a reminder alarm. Those times are around 00th minute and 30th minute.
